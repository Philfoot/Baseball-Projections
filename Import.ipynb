# %%
## Import packages ##
import pandas as pd
import numpy as np

## pybaseball sample code snipets ##
# from pybaseball import statcast
# data = statcast(start_dt='2017-06-24', end_dt='2017-06-27')
# data.head(2)

# from pybaseball import playerid_lookup
# from pybaseball import statcast_pitcher
# playerid_lookup('kershaw', 'clayton')

# kershaw_stats = statcast_pitcher('2017-06-01', '2017-07-01', 477132)
# kershaw_stats.head(2)

# from pybaseball import pitching_stats
# data1 = pitching_stats(2012, 2018)

from pybaseball import batting_stats
data2 = batting_stats(2012,2018)

# from pybaseball import schedule_and_record
# data = schedule_and_record(1927, 'NYY')
# data.head()

# from pybaseball import standings
# data = standings(2016)[4]
# print(data)

# %%
data2.head()
# Out:
#      Season          Name     Team   Age      G     AB     PA      H     1B  \
# 122  2018.0  Mookie Betts  Red Sox  25.0  136.0  520.0  614.0  180.0   96.0
# 250  2012.0  Buster Posey   Giants  25.0  148.0  530.0  610.0  178.0  114.0
# 205  2013.0    Mike Trout   Angels  21.0  157.0  589.0  716.0  190.0  115.0
# 244  2012.0    Mike Trout   Angels  20.0  139.0  559.0  639.0  182.0  117.0
# 127  2018.0    Mike Trout   Angels  26.0  140.0  471.0  608.0  147.0   80.0
#
#        2B    ...      wSL/C (pi)  wXX/C (pi)  O-Swing% (pi)  Z-Swing% (pi)  \
# 122  47.0    ...            1.93         NaN          0.185          0.535
# 250  39.0    ...           -1.11         NaN          0.251          0.588
# 205  39.0    ...            1.06         NaN          0.236          0.530
# 244  27.0    ...            3.91         NaN          0.248          0.533
# 127  24.0    ...            2.59       -5.76          0.198          0.555
#
#      Swing% (pi)  O-Contact% (pi)  Z-Contact% (pi)  Contact% (pi)  Zone% (pi)  \
# 122        0.356            0.658            0.926          0.855       0.490
# 250        0.418            0.742            0.899          0.852       0.496
# 205        0.375            0.696            0.882          0.821       0.475
# 244        0.396            0.700            0.867          0.817       0.518
# 127        0.376            0.660            0.903          0.839       0.498
#
#      Pace (pi)
# 122       23.3
# 250       22.9
# 205       24.9
# 244       23.7
# 127       23.3
#
# [5 rows x 287 columns]

# %%
data1 = pd.DataFrame(data1)
data1.to_csv("2012-2018 Pitcher.csv")

data2 = pd.DataFrame(data2)
data2.to_csv("2012-2018 Batting.csv")
